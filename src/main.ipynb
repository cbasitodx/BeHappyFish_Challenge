# %%
# !nvidia-smi
# Out:
# Wed Jan 29 01:48:26 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.94                 Driver Version: 560.94         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060      WDDM  |   00000000:07:00.0  On |                  N/A |
# |  0%   43C    P8             23W /  170W |     339MiB /  12288MiB |      7%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
print(torch.cuda.is_available())  # Debe devolver True si tu GPU es detectada
print(torch.cuda.current_device())  # Muestra el ID de la GPU actual
print(torch.cuda.get_device_name(0))  # Muestra el nombre de tu GPU
# Out:
# True
# 0
# NVIDIA GeForce RTX 3060

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics 8.3.69 🚀 Python-3.12.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# Setup complete ✅ (16 CPUs, 15.9 GB RAM, 689.4/930.7 GB disk)
#
# OS                  Windows-11-10.0.22631-SP0
# Environment         Windows
# Python              3.12.6
# Install             pip
# RAM                 15.92 GB
# Disk                689.4/930.7 GB
# CPU                 AMD Ryzen 7 5800X 8-Core Processor
# CPU count           16
# GPU                 NVIDIA GeForce RTX 3060, 12288MiB
# GPU count           1
# CUDA                11.8
#
# numpy               ✅ 2.0.2>=1.23.0
# numpy               ✅ 2.0.2<2.0.0; sys_platform == "darwin"
# matplotlib          ✅ 3.10.0>=3.3.0
# opencv-python       ✅ 4.11.0.86>=4.6.0
# pillow              ✅ 11.0.0>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.32.3>=2.23.0
# scipy               ✅ 1.15.1>=1.4.1
# torch               ✅ 2.6.0+cu118>=1.8.0
# ...

# %%
torch.cuda.empty_cache()

# !yolo task=detect mode=train model=yolo11m.pt data="C:/Users/capde/Desktop/IA/YOLOv11/aquarium_pretrain/data.yaml" epochs=20 imgsz=640 device=0
# Out:
# Ultralytics 8.3.69 🚀 Python-3.12.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
Image(filename='runs/detect/train13/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train13/results.png', width=600)
